# %% [markdown]
# Task:
#
# Count the number of each letter in a sentence.
# The department you work for undertook a project construction that makes word / text analysis. You are asked to calculate the number of letters or any chars in the sentences entered under this project.
# Write a Python program that;
# takes a sentence from the user,
# counts the number of each letter of the sentence,
# collects the letters/chars as a key and the counted numbers as a value in a dictionary.
#
# Examples
# Sample inputs	Outputs
# hippo runs to us!
# {'s': 2, 'r': 1, 't': 1, 'h': 1, 'n': 1,
# 'i': 1, 'u': 2, 'o': 2, 'p': 2, ' ': 3, '!': 1}

# %% [markdown]
# Görev:
#
# Bir cümledeki her harfin sayısını sayın.
# Çalıştığınız departman kelime/metin analizi yapan bir proje yapımını üstlenmiştir. Bu proje kapsamında girilen cümlelerdeki harf veya karakter sayısını hesaplamanız istenmektedir.
# Bir Python programı yazın;
# kullanıcıdan bir cümle alır,
# cümlenin her harfinin sayısını sayar,
# Harfleri/karakterleri anahtar olarak , sayılan sayıları ise bir sözlükte değer olarak toplar .
#
# Örnekler
# Örnek girişler	çıktılar
# su aygırı bize koşuyor!
# {'s': 2, 'r': 1, 't': 1, 'h': 1, 'n': 1,
# 'i': 1, 'u': 2, 'o': 2, ' p': 2, ' ': 3, '!': 1}

# %%
sentence = list('clarusway-it-school')
print([i for i in sentence])
print(set(sentence))
print({i: sentence.count(i) for i in sentence})
# Out:
# ['c', 'l', 'a', 'r', 'u', 's', 'w', 'a', 'y', '-', 'i', 't', '-', 's', 'c', 'h', 'o', 'o', 'l']
# {'s', 'i', 'l', 'o', '-', 'u', 'a', 'w', 'h', 't', 'c', 'y', 'r'}
# {'c': 2, 'l': 2, 'a': 2, 'r': 1, 'u': 1, 's': 2, 'w': 1, 'y': 1, '-': 2, 'i': 1, 't': 1, 'h': 1, 'o': 2}

# %%
sentence = list('clarusway-it-school')
[i for i in sentence]
print({i: sentence.count(i) for i in sentence})
# Out:
# {'c': 2, 'l': 2, 'a': 2, 'r': 1, 'u': 1, 's': 2, 'w': 1, 'y': 1, '-': 2, 'i': 1, 't': 1, 'h': 1, 'o': 2}

# %%
sentence = input("Enter a sentence : ").lower()
letters = {}
for i in sentence:
    a = 0
    b = i
    a = sentence.count(i)
    letters[i] = a
print(letters)
# Out:
# {'c': 2, 'l': 2, 'a': 2, 'r': 1, 'u': 1, 's': 2, 'w': 1, 'y': 1, '-': 2, 'ı': 1, 't': 1, 'h': 1, 'o': 2}

# %%
text = input("Enter a sentence:")
def count(text):
    dict = {}
    for n in text:
        keys = dict.keys()
        if n in keys:
            dict[n] += 1
        else:
            dict[n] = 1
    return dict
print(count(text))
# Out:
# {'c': 2, 'l': 2, 'a': 2, 'r': 1, 'u': 1, 's': 2, 'w': 1, 'y': 1, '-': 2, 'ı': 1, 't': 1, 'h': 1, 'o': 2}

# %%
text = 'clarusway-ıt-school'
dictt = {}
for i in text:
    dictt[i] = dictt.get(i, 0) + 1
print(dictt)
# Out:
# {'c': 2, 'l': 2, 'a': 2, 'r': 1, 'u': 1, 's': 2, 'w': 1, 'y': 1, '-': 2, 'ı': 1, 't': 1, 'h': 1, 'o': 2}

# %%
text = ('clarusway-ıt-school')
x = dictt = {}
for i in text:
    dictt[i] = (lambda x : text.count(i))(i)
print(x)
# Out:
# {'c': 2, 'l': 2, 'a': 2, 'r': 1, 'u': 1, 's': 2, 'w': 1, 'y': 1, '-': 2, 'ı': 1, 't': 1, 'h': 1, 'o': 2}

# %%
sentence = list('clarusway-ıt-school')
lettersinsentence = set(sorted('clarusway-ıt-school'))
print(sentence,lettersinsentence, sep = '\n')
x = {'l': (lambda  l: sentence.count(l))('l'),
     'o':(lambda o : sentence.count(o))('o'),
     's': (lambda s: sentence.count(s))('s'),
     'c': (lambda c : sentence.count(c))('c'),
     'w': (lambda w : sentence.count(w))('w'),
     'a': (lambda a : sentence.count(a))('a'),
     'h': (lambda h : sentence.count(h))('h'),
     'ı': (lambda ı : sentence.count(ı))('ı'),
     't': (lambda t : sentence.count(t))('t'),
     'y': (lambda y : sentence.count(y))('y'),
     'u': (lambda u : sentence.count(u))('u'),
     '-': (lambda x : sentence.count(x))('-'),
     'r': (lambda r : sentence.count(r))('r')}
print(x)
# Out:
# ['c', 'l', 'a', 'r', 'u', 's', 'w', 'a', 'y', '-', 'ı', 't', '-', 's', 'c', 'h', 'o', 'o', 'l']
# {'s', 'a', 'l', 'h', 'y', 'r', 't', 'c', 'ı', 'u', 'o', '-', 'w'}
# {'l': 2, 'o': 2, 's': 2, 'c': 2, 'w': 1, 'a': 2, 'h': 1, 'ı': 1, 't': 1, 'y': 1, 'u': 1, '-': 2, 'r': 1}

# %%
sentence = input("Enter sentence: ")
def count_letters(sentence):
    dict = {}
    for i in sentence:
        keys = dict.keys()
        if i in keys:
            dict[i] += 1
        else:
            dict[i] = 1
    return dict
print(count_letters(sentence))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
